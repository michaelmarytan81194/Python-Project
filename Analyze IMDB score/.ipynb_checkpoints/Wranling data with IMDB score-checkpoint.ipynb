# %%
#1. Extract data
import pandas as pd
read_xlsx = pd.ExcelFile('imdb.xlsx')
df = read_xlsx.parse('imdb')
df
# Out:
#                                         movie_title  director_id  country_id  \
# 0                         The Shawshank RedemptionÊ           34           1
# 1                                    The GodfatherÊ           33           1
# 2                                  The Dark KnightÊ           16           1
# 3                           The Godfather: Part IIÊ           33           1
# 4    The Lord of the Rings: The Return of the KingÊ           83           1
# ..                                              ...          ...         ...
# 173                The Perks of Being a WallflowerÊ          101           1
# 174                                         BrazilÊ          106           8
# 175                                       Big FishÊ          108           1
# 176                                   True RomanceÊ          112           1
# 177                                     PersepolisÊ          114           7
#
# ...

# %%
#2.1 Import other sheets - directors
df_directors = read_xlsx.parse('directors')
df_directors
# Out:
#       id          director_name
# 0      1         Akira Kurosawa
# 1      2     Alejandro Amenabar
# 2      3  Alejandro G. Inarritu
# 3      3  Alejandro G. Inarritu
# 4      4       Alfred Hitchcock
# ..   ...                    ...
# 173  113         Victor Fleming
# 174  114      Vincent Paronnaud
# 175  115           Wes Anderson
# 176  116      Wolfgang Petersen
# 177  117            Woody Allen
#
# [178 rows x 2 columns]

# %%
#2.2 Import other sheets - countries
df_countries = read_xlsx.parse('countries')
df_countries
# Out:
#     id       country
# 0    1           USA
# 1    2         Italy
# 2    3   New Zealand
# 3    4         Japan
# 4    5        Brazil
# 5    6       Germany
# 6    7        France
# 7    8            UK
# 8    9   South Korea
# 9   10         India
# 10  11          Iran
# 11  12  West Germany
# 12  13       Denmark
# 13  14       Ireland
# 14  15        Canada
# 15  16     Argentina
# 16  17         Spain
# 17  18        Mexico
# 18  19     Australia

# %%
#3. The numnber of directors
count = df_directors['id'].value_counts()
count
# Out:
# 16     7
# 71     6
# 85     6
# 103    5
# 90     4
#       ..
# 43     1
# 42     1
# 41     1
# 39     1
# 117    1
# Name: id, Length: 117, dtype: int64

# %%
director_clean = df_directors.drop_duplicates()
director_clean
# Out:
#       id          director_name
# 0      1         Akira Kurosawa
# 1      2     Alejandro Amenabar
# 2      3  Alejandro G. Inarritu
# 4      4       Alfred Hitchcock
# 5      5         Andrew Stanton
# ..   ...                    ...
# 172  113         Victor Fleming
# 174  114      Vincent Paronnaud
# 175  115           Wes Anderson
# 176  116      Wolfgang Petersen
# 177  117            Woody Allen
#
# [117 rows x 2 columns]
