# %%
#1. Import necessary libraries
import requests
import sqlite3
import pandas as pd
from bs4 import BeautifulSoup

# %%
#2. Necessary Args
url = 'https://web.archive.org/web/20230902185655/https://en.everybodywiki.com/100_Most_Highly-Ranked_Films'
db_name = 'Movies.db'
table_name = 'Top_25'
df = pd.DataFrame(columns=["Film","Year", "Rotten Tomatoes' Top 100"])
count = 0

# %%
#3. Get data from the HTML to str
html_page = requests.get(url).text
html_page #type:str
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head><script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript"></script>\n<script type="text/javascript">window.addEventListener(\'DOMContentLoaded\',function(){var v=archive_analytics.values;v.service=\'wb\';v.server_name=\'wwwb-app212.us.archive.org\';v.server_ms=473;archive_analytics.send_pageview({});});</script>\n<script type="text/javascript" src="//web-static.archive.org/_static/js/bundle-playback.js?v=6XRi73ky" charset="utf-8"></script>\n<script type="text/javascript" src="//web-static.archive.org/_static/js/wombat.js?v=txqj7nKC" charset="utf-8"></script>\n<script>window.RufflePlayer=window.RufflePlayer||{};window.RufflePlayer.config={"autoplay":"on","unmuteOverlay":"hidden"};</script>\n<script type="text/javascript" src="//web-static.archive.org/_static/js/ruffle.js"></script>\n<script type="text/javascript">\n  __wm.init("https://web.archive.org/web");\n  __wm.wombat("https://en.ever
# ...

# %%
#4. Instantiate the BeautifulSoup from str
data = BeautifulSoup(html_page, 'html.parser')
data
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head><script src="//archive.org/includes/analytics.js?v=cf34f82" type="text/javascript"></script>
# <script type="text/javascript">window.addEventListener('DOMContentLoaded',function(){var v=archive_analytics.values;v.service='wb';v.server_name='wwwb-app212.us.archive.org';v.server_ms=473;archive_analytics.send_pageview({});});</script>
# <script charset="utf-8" src="//web-static.archive.org/_static/js/bundle-playback.js?v=6XRi73ky" type="text/javascript"></script>
# <script charset="utf-8" src="//web-static.archive.org/_static/js/wombat.js?v=txqj7nKC" type="text/javascript"></script>
# <script>window.RufflePlayer=window.RufflePlayer||{};window.RufflePlayer.config={"autoplay":"on","unmuteOverlay":"hidden"};</script>
# <script src="//web-static.archive.org/_static/js/ruffle.js" type="text/javascript"></script>
# <script type="text/javascript">
#   __wm.init("https://web.archive.org/web");
# ...

# %%
#5. Get designated table
tables = data.find_all('tbody') #return a list
tables[1]
# Out:
# <tbody><tr>
# <th>Average Rank</th>
# <th>Film</th>
# <th>Year</th>
# <th>Rotten Tomatoes' Top 100<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup></th>
# <th>IMDb's Top 250 <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup></th>
# <th>Empire's Top 100 <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup></th>
# <th>AFI's Top 100 <sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup></th>
# <th>BFI's Top 100 <sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup>
# </th></tr>
# <tr>
# <td>1</td>
# <td>The Godfather</td>
# <td>1972</td>
# <td>17</td>
# <td>2</td>
# <td>3</td>
# <td>2</td>
# <td>21
# </td></tr>
# <tr>
# <td>2</td>
# <td>Citizen Kane</td>
# <td>1941</td>
# <td>2</td>
# <td>93</td>
# <td>40</td>
# <td>1</td>
# <td>2
# </td></tr>
# <tr>
# <td>3</td>
# <td>Casablanca</td>
# <td>1942</td>
# <td>8</td>
# <td>42</td>
# <td>33</td>
# <td>3</td>
# <td>84
# ...

# %%
#get the content of target table
rows = tables[1].find_all('tr')
rows
# Out:
# [<tr>
#  <th>Average Rank</th>
#  <th>Film</th>
#  <th>Year</th>
#  <th>Rotten Tomatoes' Top 100<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup></th>
#  <th>IMDb's Top 250 <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup></th>
#  <th>Empire's Top 100 <sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup></th>
#  <th>AFI's Top 100 <sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup></th>
#  <th>BFI's Top 100 <sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup>
#  </th></tr>,
#  <tr>
#  <td>1</td>
#  <td>The Godfather</td>
#  <td>1972</td>
#  <td>17</td>
#  <td>2</td>
#  <td>3</td>
#  <td>2</td>
#  <td>21
#  </td></tr>,
#  <tr>
#  <td>2</td>
#  <td>Citizen Kane</td>
#  <td>1941</td>
#  <td>2</td>
#  <td>93</td>
#  <td>40</td>
#  <td>1</td>
#  <td>2
#  </td></tr>,
#  <tr>
#  <td>3</td>
#  <td>Casablanca</td>
#  <td>1942</td>
#  <td>8</td>
#  <td>42</td>
#  <td>33</td>
# ...

# %%
for row in rows:
    if count <= 25:
        col = row.find_all('td')
        if len(col) != 0:
            data_dict = {
                        "Film": col[1].contents[0],
                         "Year": col[2].contents[0],
                        "Rotten Tomatoes' Top 100": col[3].contents[0]
                        }
            df1 = pd.DataFrame(data_dict, index=[0])
            df = pd.concat([df, df1], ignore_index = True)
        count +=1
    else:
        break
df
# Out:
#                                              Film  Year  \
# 0                                   The Godfather  1972
# 1                                    Citizen Kane  1941
# 2                                      Casablanca  1942
# 3                          The Godfather, Part II  1974
# 4                             Singin' in the Rain  1952
# 5                                          Psycho  1960
# 6                                     Rear Window  1954
# 7                                  Apocalypse Now  1979
# 8                           2001: A Space Odyssey  1968
# 9                                   Seven Samurai  1954
# 10                                        Vertigo  1958
# 11                                    Sunset Blvd  1950
# 12                                   Modern Times  1936
# 13                             Lawrence of Arabia  1962
# 14                             North by Northwest  1959
# 15                                      Star Wars  1977
# ...

# %%
import sqlalchemy

# Connect to the database
conn = sqlalchemy.create_engine(
'mysql+mysqlconnector://root:somepw@localhost:3306/movies') #CHANGE PASSWORD
df.to_sql(table_name, conn, if_exists='replace', index=False)
# Out:
# C:\Users\vagy1255\AppData\Local\Temp\ipykernel_3440\841750955.py:6: UserWarning: The provided table name 'Top_25' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(table_name, conn, if_exists='replace', index=False)
# 25
