# %%
pip install docxtpl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 5.6/5.6 MB 520.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for docxcompose: filename=docxcompose-1.4.0-py3-none-any.whl size=23301 sha256=f70896cfab0df3ad0c72c04d39def51803cc1b61be156dfdd582b9f318a29937
#   Stored in directory: c:\users\vagy1255\appdata\local\pip\cache\wheels\0a\73\65\8408707e3f0eb9086c0fdeeeac0cf04cdacf1826d84fb79a34
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184519 sha256=7e9b3fd63894678afc34b20d39fb992ecb73390ac418040e3668cdeaa7126cdf
#   Stored in directory: c:\users\vagy1255\appdata\local\pip\cache\wheels\65\e1\9b\0c38fe6cfe02a9fe31cb6b4efd90985f17354d7f77872f2def
# ...

# %%
from docxtpl import DocxTemplate

doc = DocxTemplate("Word.docx")
context = { 'Name' : "World company" }
doc.render(context)
doc.save("generated_doc.docx")

# %%
handle_excel = pd.ExcelFile("Excel.xlsx")
data = handle_excel.parse('Sheet1')
data.head()
# Out:
#                           AD Name  Agent code         Agent Nam      Paid  \
# 0  Hồ Thị Hà                      60023940  ĐOÀN THỊ KIỀU  27556000
# 1  Phạm Phương Liên                 60041658  TRƯƠNG KIM CHUNG  10164000
# 2  Phạm Phương Liên                 60051367    LƯU MINH TIẾN  10390000
# 3  Nguyễn Trường Đỉnh             60075234  PHAN NGỌC HƯƠNG  50995000
# 4  Đoàn Thị Lâm                    60077941   TRẦN THỊ XUÂN   9190000
#
#     Return Gender      Phone  \
# 0  7724000    Chị  388239612
# 1  2268000    Chị  946149601
# 2  3938000    Anh  828984935
# 3  7410000    Chị  909353518
# 4  1230000    Chị  868238672
#
#                                                  Add
# 0  Buôn Bưng A  Xã Ea Lâm Huyện Sông Hinh Tỉnh...
# 1  Ấp 1  Xã Khánh Bình Tây Bắc Huyện Trần ...
# 2  Sào Lưới B  Xã Khánh Bình Tây Bắc Huyện...
# 3  193 NGUYỄN XÍ  Phường 26 Quận Bình Thạnh...
# 4  Thôn Bình Thanh  Xã Ia Drăng Huyện Chư Prôn...

# %%
import pandas as pd
handle_excel = pd.ExcelFile("Excel_Final.xlsx")
data = handle_excel.parse('Sheet1')
# my_context = {'Name': Name, 'Add': Add, 'AgentCode': AgentCode, 'Phone': Phone, 'Office': Office, 'AD': AD, 
      #       'Gender': Gender, 'Paid': Paid,  'Return': Return}
for index, row in data.iterrows():
    context = { 
        'Name' : row['Agent Nam'],
        'Add': row['Add'],
        'AgentCode' : row['Agent code'],
        'Phone': row['Phone'],
        'Office': row['Area_Name'],
        'AD': row['AD Name'],
        'Gender': row['Gender'],
        'Paid': row['Paid'],
        'Return': row['Return']
    }
    doc.render(context)
    doc.save(f"{row['Agent Nam']}.docx")
